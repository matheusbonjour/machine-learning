# %% [markdown]
# <a href="https://www.kaggle.com/code/matheusbonjour/reading-netcdf-files?scriptVersionId=204662330" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import xarray as xr # to read netcdf files 


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/waverys-swsa-2018-2020/cmems_mod_glo_wav_my_0.2deg_PT3H-i_VHM0-VMDR-VTPK_60.00W-30.00W_45.00S-10.00S_2020-01-01-2020-12-31.nc
# /kaggle/input/waverys-swsa-2018-2020/cmems_mod_glo_wav_my_0.2deg_PT3H-i_VHM0-VMDR-VTPK_60.00W-30.00W_45.00S-10.00S_2019-01-01-2019-12-31.nc
# /kaggle/input/waverys-swsa-2018-2020/cmems_mod_glo_wav_my_0.2deg_PT3H-i_VHM0-VMDR-VTPK_60.00W-30.00W_45.00S-10.00S_2018-01-01-2018-12-31.nc

# %%
data_path = '/kaggle/input/waverys-swsa-2018-2020/'
files = os.listdir(data_path)
files = [f for f in files if 'wav' in f]
files = [data_path + f for f in files]

waverys = xr.open_mfdataset(files, combine='by_coords')

# %% [markdown]
# **The function xr.open_mfdataset() in Xarray is used to read multiple NetCDF files into a single dataset.
# This is particularly useful when handling time-series data stored across multiple files. In the example, files matching a specific pattern are selected, and Xarray combines them 'by_coords', ensuring consistency in coordinates across files. This allows for seamless analysis of large datasets split into multiple files,effectively managing and merging them into a cohesive data structure for further operations.**

# %%
waverys
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:    (time: 8768, latitude: 176, longitude: 151)
# Coordinates:
#   * latitude   (latitude) float32 704B -45.0 -44.8 -44.6 ... -10.4 -10.2 -10.0
#   * longitude  (longitude) float32 604B -60.0 -59.8 -59.6 ... -30.4 -30.2 -30.0
#   * time       (time) datetime64[ns] 70kB 2018-01-01 ... 2020-12-31T21:00:00
# Data variables:
#     VHM0       (time, latitude, longitude) float64 2GB dask.array<chunksize=(2920, 176, 151), meta=np.ndarray>
#     VMDR       (time, latitude, longitude) float64 2GB dask.array<chunksize=(2920, 176, 151), meta=np.ndarray>
#     VTPK       (time, latitude, longitude) float64 2GB dask.array<chunksize=(2920, 176, 151), meta=np.ndarray>
# Attributes: (12/31)
#     CDI:                           Climate Data Interface version 1.9.8 (http...
#     CDO:                           Climate Data Operators version 1.9.8 (http...
#     Conventions:                   CF-1.6
#     area:                          GLO
# ...

# %% [markdown]
# **If you want to read just an specified data, you can follow the next steps**

# %%
data_path = '/kaggle/input/waverys-swsa-2018-2020/'
data1 = data_path + "cmems_mod_glo_wav_my_0.2deg_PT3H-i_VHM0-VMDR-VTPK_60.00W-30.00W_45.00S-10.00S_2018-01-01-2018-12-31.nc"

waverys_data1 = xr.open_dataset(data1)

waverys_data1
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:    (time: 2920, latitude: 176, longitude: 151)
# Coordinates:
#   * latitude   (latitude) float32 704B -45.0 -44.8 -44.6 ... -10.4 -10.2 -10.0
#   * longitude  (longitude) float32 604B -60.0 -59.8 -59.6 ... -30.4 -30.2 -30.0
#   * time       (time) datetime64[ns] 23kB 2018-01-01 ... 2018-12-31T21:00:00
# Data variables:
#     VHM0       (time, latitude, longitude) float64 621MB ...
#     VMDR       (time, latitude, longitude) float64 621MB ...
#     VTPK       (time, latitude, longitude) float64 621MB ...
# Attributes: (12/31)
#     CDI:                           Climate Data Interface version 1.9.8 (http...
#     CDO:                           Climate Data Operators version 1.9.8 (http...
#     Conventions:                   CF-1.6
#     area:                          GLO
#     contact:                       servicedesk.cmems@mercator-ocean.eu
#     credit:                        E.U. Copernicus Marine Service Information...
# ...

# %% [markdown]
# **Look to the time coordinate: In the first, we have 3 years of data (2018, 2019, 2020) and in the second, we have just one year (2018)**
